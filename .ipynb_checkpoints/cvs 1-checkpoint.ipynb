# %%
import matplotlib.pyplot as plt
import csv


x=[]
y=[]

with open("Book2.csv","r") as va:
    file=csv.reader(va)
    
    for col  in file:
        x.append(col[0])
        y.append(col[1])
        
plt.plot(x,y)

plt.show()
