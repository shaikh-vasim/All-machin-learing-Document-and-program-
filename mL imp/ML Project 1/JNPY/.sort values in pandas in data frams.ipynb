# %%
import pandas as pd

bank=pd.read_csv("bank_marketing_dataset.csv")
bank.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct      79.0         1   -1.0         0  unknown  no
# 1  cellular   11   may     220.0         1  339.0         4  failure  no
# 2  cellular   16   apr     185.0         1  330.0         1  failure  no
# 3   unknown    3   jun     199.0         4   -1.0         0  unknown  no
# 4   unknown    5   may     226.0         1   -1.0         0  unknown  no

# %%
bank.sort_values("job").head()
# Out:
#       age     job   marital  education default  balance housing loan  \
# 3879   25  admin.    single   tertiary      no     1420      no   no
# 3559   36  admin.    single  secondary      no      319     yes   no
# 4244   39  admin.  divorced  secondary      no       83     yes   no
# 2365   33  admin.  divorced  secondary      no      661     yes   no
# 4240   45  admin.   married  secondary      no     -547     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 3879  cellular    8   apr     124.0         2   -1.0         0  unknown  no
# 3559  cellular   18   may     120.0         2   -1.0         0  unknown  no
# 4244  cellular   30   jul      69.0         6   -1.0         0  unknown  no
# 2365  cellular   18   nov     411.0         1  173.0         2    other  no
# 4240   unknown    3   jun     214.0         2   -1.0         0  unknown  no

# %%
bank.sort_values("job",ascending=False)
# Out:
#       age      job  marital  education default  balance housing loan  \
# 95     41  unknown   single   tertiary      no     1567      no   no
# 2711   47  unknown  married    unknown      no      677      no   no
# 3385   38  unknown   single   tertiary      no        0      no   no
# 2477   53  unknown  married    primary      no      732      no   no
# 2486   50  unknown  married    unknown      no      558      no   no
# ...   ...      ...      ...        ...     ...      ...     ...  ...
# 3931   47   admin.  married  secondary      no     3676      no   no
# 875    37   admin.  married  secondary      no    11303      no   no
# 880    26   admin.   single  secondary      no      255      no   no
# 2409   32   admin.   single  secondary      no     1649      no   no
# 1332   45   admin.  married  secondary      no      204     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
bank.sort_values("job",ascending="false").head()
# Out:
#       age     job   marital  education default  balance housing loan  \
# 3879   25  admin.    single   tertiary      no     1420      no   no
# 3559   36  admin.    single  secondary      no      319     yes   no
# 4244   39  admin.  divorced  secondary      no       83     yes   no
# 2365   33  admin.  divorced  secondary      no      661     yes   no
# 4240   45  admin.   married  secondary      no     -547     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 3879  cellular    8   apr     124.0         2   -1.0         0  unknown  no
# 3559  cellular   18   may     120.0         2   -1.0         0  unknown  no
# 4244  cellular   30   jul      69.0         6   -1.0         0  unknown  no
# 2365  cellular   18   nov     411.0         1  173.0         2    other  no
# 4240   unknown    3   jun     214.0         2   -1.0         0  unknown  no

# %%
bank.sort_values("job",na_position="first")
# Out:
#       age      job   marital  education default  balance housing loan  \
# 3879   25   admin.    single   tertiary      no     1420      no   no
# 3559   36   admin.    single  secondary      no      319     yes   no
# 4244   39   admin.  divorced  secondary      no       83     yes   no
# 2365   33   admin.  divorced  secondary      no      661     yes   no
# 4240   45   admin.   married  secondary      no     -547     yes   no
# ...   ...      ...       ...        ...     ...      ...     ...  ...
# 3990   49  unknown   married  secondary      no        0      no   no
# 3986   30  unknown    single   tertiary      no     6836      no   no
# 1569   43  unknown    single    unknown      no      181      no   no
# 95     41  unknown    single   tertiary      no     1567      no   no
# 2047   43  unknown   married   tertiary      no     1937      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
bank.sort_values("job",na_position="last")
# Out:
#       age      job   marital  education default  balance housing loan  \
# 3879   25   admin.    single   tertiary      no     1420      no   no
# 3559   36   admin.    single  secondary      no      319     yes   no
# 4244   39   admin.  divorced  secondary      no       83     yes   no
# 2365   33   admin.  divorced  secondary      no      661     yes   no
# 4240   45   admin.   married  secondary      no     -547     yes   no
# ...   ...      ...       ...        ...     ...      ...     ...  ...
# 3990   49  unknown   married  secondary      no        0      no   no
# 3986   30  unknown    single   tertiary      no     6836      no   no
# 1569   43  unknown    single    unknown      no      181      no   no
# 95     41  unknown    single   tertiary      no     1567      no   no
# 2047   43  unknown   married   tertiary      no     1937      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome   y
# ...
