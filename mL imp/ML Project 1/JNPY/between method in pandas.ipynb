# %%
import pandas as pd

comp=pd.read_csv("computer_hardware_dataset.csv")
comp.head()
# Out:
#   vendor_name model_name  MYCT  MMIN   MMAX  CACH  CHMIN  CHMAX  PRP  ERP
# 0     adviser      32/60   125   256   6000   256     16    128  198  199
# 1      amdahl     470v/7    29  8000  32000    32      8     32  269  253
# 2      amdahl    470v/7a    29  8000  32000    32      8     32  220  253
# 3      amdahl    470v/7b    29  8000  32000    32      8     32  172  253
# 4      amdahl    470v/7c    29  8000  16000    32      8     16  132  132

# %%
comp["PRP"].between(100,230)
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 204    False
# 205    False
# 206    False
# 207    False
# 208    False
# Name: PRP, Length: 209, dtype: bool

# %%
comp[comp["PRP"].between(100,230)]
# Out:
#     vendor_name        model_name  MYCT  MMIN   MMAX  CACH  CHMIN  CHMAX  PRP  \
# 0       adviser             32/60   125   256   6000   256     16    128  198
# 2        amdahl           470v/7a    29  8000  32000    32      8     32  220
# 3        amdahl           470v/7b    29  8000  32000    32      8     32  172
# 4        amdahl           470v/7c    29  8000  16000    32      8     16  132
# 13         basf              7/68    50  4000  16000    65      1      8  138
# 19    burroughs             b4955   110  5000   5000   142      8     64  120
# 34          cdc     cyber:170/835    56  5240  20970    30     12     24  106
# 35          cdc     cyber:170/845    64  5240  20970    30     12     24  208
# 52           dg  eclipse:mv/10000   140  1000  16000    16      1      3  138
# 63        gould   concept:32/8705    75  2000   8000    64      1     38  144
# 64        gould   concept:32/8750    75  2000  16000    64      1     38  144
# ...

# %%
comp["CHMAX"].between(100,105)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 204    False
# 205    False
# 206    False
# 207    False
# 208    False
# Name: CHMAX, Length: 209, dtype: bool

# %%
comp[comp["CHMAX"].between(100,105)]
# Out:
#     vendor_name model_name  MYCT  MMIN   MMAX  CACH  CHMIN  CHMAX  PRP  ERP
# 196      sperry    1100/83    50  2000  32000   112     52    104  307  341
# 197      sperry    1100/84    50  4000  32000   112     52    104  397  360
