# %%
import matplotlib.pyplot as plt



x = [1,2,3,4,5]

y = [25,14,25,14,35] 
#  

tick_label=['one','vasim','three',"four","five"]

plt.bar(x,y,tick_label=tick_label,width=0.75,color=["green","red","blue"])

plt.xlabel("x-axis",size=16)
plt.ylabel("y-axis",size=16)
plt.title("vasim shaikh bar garph",size=19,color="green")
plt.show()
