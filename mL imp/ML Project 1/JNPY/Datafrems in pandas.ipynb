# %%
import pandas as pd

bank=pd.read_csv("bank_marketing_dataset.csv")
bank.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct      79.0         1   -1.0         0  unknown  no
# 1  cellular   11   may     220.0         1  339.0         4  failure  no
# 2  cellular   16   apr     185.0         1  330.0         1  failure  no
# 3   unknown    3   jun     199.0         4   -1.0         0  unknown  no
# 4   unknown    5   may     226.0         1   -1.0         0  unknown  no

# %%
bank.head(15)
# Out:
#     age            job  marital  education default  balance  ... duration campaign  pdays  previous poutcome    y
# 0    30     unemployed  married    primary      no     1787  ...     79.0        1   -1.0         0  unknown   no
# 1    33       services  married  secondary      no     4789  ...    220.0        1  339.0         4  failure   no
# 2    35     management   single   tertiary      no     1350  ...    185.0        1  330.0         1  failure   no
# 3    30     management  married   tertiary      no     1476  ...    199.0        4   -1.0         0  unknown   no
# 4    59    blue-collar  married  secondary      no        0  ...    226.0        1   -1.0         0  unknown   no
# 5    35     management   single   tertiary      no      747  ...    141.0        2  176.0         3  failure   no
# 6    36  self-employed  married   tertiary      no      307  ...    341.0        1  330.0         2    other   no
# ...

# %%
bank.tail(15)
# Out:
#       age            job   marital  education default  balance  ... duration campaign  pdays  previous poutcome    y
# 4506   42     unemployed  divorced   tertiary      no     -166  ...     85.0        4   -1.0         0  unknown   no
# 4507   33       services   married  secondary      no      288  ...    306.0        1   -1.0         0  unknown   no
# 4508   42         admin.   married    unknown      no      642  ...    509.0        2   -1.0         0  unknown   no
# 4509   51     technician   married   tertiary      no     2506  ...    210.0        3   -1.0         0  unknown   no
# 4510   36     technician  divorced  secondary      no      566  ...    129.0        2   -1.0         0  unknown   no
# 4511   46    blue-collar   married  secondary      no      668  ...   1263.0        2   -1.0         0  unknown  yes
# 4512   40    blue-collar   married  secondary      no     1100  ...    660.0        2   -1.0         0  unknown   no
# ...

# %%
bank.shape
# Out:
# (4521, 17)

# %%
bank.index
# Out:
# RangeIndex(start=0, stop=4521, step=1)

# %%
bank.dtypes
# Out:
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance        int64
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# duration     float64
# campaign       int64
# pdays        float64
# previous       int64
# poutcome      object
# y             object
# dtype: object

# %%
# datafremas function

bank.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
bank.axes
# Out:
# [RangeIndex(start=0, stop=4521, step=1),
#  Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#         'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#         'previous', 'poutcome', 'y'],
#        dtype='object')]

# %%
bank.info
# Out:
# <bound method DataFrame.info of       age            job  marital  education default  balance  ... duration campaign  pdays  previous poutcome   y
# 0      30     unemployed  married    primary      no     1787  ...     79.0        1   -1.0         0  unknown  no
# 1      33       services  married  secondary      no     4789  ...    220.0        1  339.0         4  failure  no
# 2      35     management   single   tertiary      no     1350  ...    185.0        1  330.0         1  failure  no
# 3      30     management  married   tertiary      no     1476  ...    199.0        4   -1.0         0  unknown  no
# 4      59    blue-collar  married  secondary      no        0  ...    226.0        1   -1.0         0  unknown  no
# ...   ...            ...      ...        ...     ...      ...  ...      ...      ...    ...       ...      ...  ..
# 4516   33       services  married  secondary      no     -333  ...    329.0        5   -1.0         0  unknown  no
# ...

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   float64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   float64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: float64(2), int64(5), object(10)
# memory usage: 423.9+ KB

# %%
bank.get_dtype_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-9df4eac61b2a> in <module>
# ----> 1 bank.get_dtype_counts()
#
# c:\python 3.8.3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_dtype_counts'
