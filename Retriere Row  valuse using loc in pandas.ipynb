# %%
import pandas as pd

comp=pd.read_csv("bank_marketing_dataset.csv",index_col=["age"])
comp.tail()
# Out:
#                job  marital  education default  balance housing loan  \
# age
# 33        services  married  secondary      no     -333     yes   no
# 57   self-employed  married   tertiary     yes    -3313     yes  yes
# 57      technician  married  secondary      no      295      no   no
# 28     blue-collar  married  secondary      no     1137      no   no
# 44    entrepreneur   single   tertiary      no     1136     yes  yes
#
#       contact  day month  duration  campaign  pdays  previous poutcome   y
# age
# 33   cellular   30   jul     329.0         5   -1.0         0  unknown  no
# 57    unknown    9   may     153.0         1   -1.0         0  unknown  no
# 57   cellular   19   aug     151.0        11   -1.0         0  unknown  no
# 28   cellular    6   feb     129.0         4  211.0         3    other  no
# 44   cellular    3   apr     345.0         2  249.0         7    other  no

# %%
comp.loc[50]
# Out:
#                job   marital  education default  balance housing loan  \
# age
# 50     blue-collar  divorced    primary      no      388      no   no
# 50   self-employed   married   tertiary      no     4012      no   no
# 50     blue-collar   married  secondary      no      606     yes   no
# 50     blue-collar   married    primary      no     5776      no   no
# 50     blue-collar   married    primary      no     4108     yes   no
# ..             ...       ...        ...     ...      ...     ...  ...
# 50      management  divorced   tertiary      no      100     yes  yes
# 50      management   married   tertiary      no    19447     yes  yes
# 50     blue-collar   married    unknown      no     2284     yes   no
# 50      unemployed   married  secondary      no     3357      no   no
# 50     blue-collar   married  secondary      no      181     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# age
# ...

# %%
comp.loc[30]
# Out:
#              job   marital  education default  balance housing loan   contact  \
# age
# 30    unemployed   married    primary      no     1787      no   no  cellular
# 30    management   married   tertiary      no     1476     yes  yes   unknown
# 30        admin.    single   tertiary      no      261      no   no  cellular
# 30      services   married  secondary      no     1808     yes   no  cellular
# 30    management    single   tertiary      no     1372      no   no  cellular
# ..           ...       ...        ...     ...      ...     ...  ...       ...
# 30    technician    single  secondary      no     4787     yes   no  cellular
# 30      services  divorced  secondary      no      -94     yes   no  cellular
# 30    technician   married   tertiary      no      101     yes  yes  cellular
# 30    management    single   tertiary      no     7845     yes   no   unknown
# 30   blue-collar    single  secondary      no      363      no   no  cellular
#
# ...

# %%
30 in comp.index
# Out:
# True
