# %%
import matplotlib.pyplot as plt
import time

x=[1,2,3,4]

y=["vasim","utkarsh","rohan","tribhuwan"]

color=["r","m","g","b"]
plt.pie(x,labels=y,colors=color,startangle=90,shadow=True,explode=(0.3,0,0,0),autopct="%1.2f%%")

plt.legend()


plt.show()
