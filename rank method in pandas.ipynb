# %%
import pandas as pd

bank=pd.read_csv("bank_marketing_dataset.csv")
bank.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct      79.0         1   -1.0         0  unknown  no
# 1  cellular   11   may     220.0         1  339.0         4  failure  no
# 2  cellular   16   apr     185.0         1  330.0         1  failure  no
# 3   unknown    3   jun     199.0         4   -1.0         0  unknown  no
# 4   unknown    5   may     226.0         1   -1.0         0  unknown  no

# %%
bank["balance"].rank(ascending=False).astype(int)
bank["vasim_ban"]=bank["balance"].rank(ascending=False).astype(int)

bank
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank.sort_values(by=["vasim_ban","balance"])
# Out:
#       age            job  marital  education default  balance housing loan  \
# 3700   60        retired  married    primary      no    71188      no   no
# 2989   42   entrepreneur  married   tertiary      no    42045      no   no
# 1483   43     technician   single   tertiary      no    27733     yes   no
# 1881   36     management  married   tertiary      no    27359     yes   no
# 3830   57     technician  married   tertiary      no    27069      no  yes
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 3584   46    blue-collar  married  secondary      no    -1400     yes   no
# 856    49     technician  married  secondary     yes    -1680     yes  yes
# 2538   44     management  married  secondary      no    -1746     yes   no
# 2398   51   entrepreneur  married  secondary     yes    -2082      no  yes
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
#
# ...

# %%
bank.sort_values(by=["vasim_ban","balance"]).tail(50)
# Out:
#       age            job   marital  education default  balance housing loan  \
# 1235   32       services   married  secondary      no     -632     yes  yes
# 715    30         admin.    single  secondary      no     -635      no   no
# 3548   39         admin.   married  secondary      no     -650      no   no
# 2319   44     management   married  secondary      no     -665      no   no
# 3688   38     unemployed   married  secondary      no     -673     yes   no
# 3555   44    blue-collar   married  secondary      no     -674     yes   no
# 1868   42     management   married    primary      no     -679     yes  yes
# 3493   36     management    single   tertiary      no     -679     yes  yes
# 295    49   entrepreneur  divorced    unknown     yes     -701     yes   no
# 2564   50     technician  divorced  secondary      no     -701     yes  yes
# 3155   55     technician    single   tertiary      no     -703     yes   no
# ...
