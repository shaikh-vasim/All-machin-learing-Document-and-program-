# %%
import pandas as pd

comp=pd.read_csv("computer_hardware_dataset.csv")
comp.head()
# Out:
#   vendor_name model_name  MYCT  MMIN   MMAX  CACH  CHMIN  CHMAX  PRP  ERP
# 0     adviser      32/60   125   256   6000   256     16    128  198  199
# 1      amdahl     470v/7    29  8000  32000    32      8     32  269  253
# 2      amdahl    470v/7a    29  8000  32000    32      8     32  220  253
# 3      amdahl    470v/7b    29  8000  32000    32      8     32  172  253
# 4      amdahl    470v/7c    29  8000  16000    32      8     16  132  132

# %%
comp
# Out:
#     vendor_name     model_name  MYCT  MMIN   MMAX  CACH  CHMIN  CHMAX  PRP  \
# 0       adviser          32/60   125   256   6000   256     16    128  198
# 1        amdahl         470v/7    29  8000  32000    32      8     32  269
# 2        amdahl        470v/7a    29  8000  32000    32      8     32  220
# 3        amdahl        470v/7b    29  8000  32000    32      8     32  172
# 4        amdahl        470v/7c    29  8000  16000    32      8     16  132
# ..          ...            ...   ...   ...    ...   ...    ...    ...  ...
# 204      sperry           80/8   124  1000   8000     0      1      8   42
# 205      sperry  90/80-model-3    98  1000   8000    32      2      8   46
# 206      sratus             32   125  2000   8000     0      2     14   52
# 207        wang         vs-100   480   512   8000    32      0      0   67
# 208        wang          vs-90   480  1000   4000     0      0      0   45
#
#      ERP
# 0    199
# 1    253
# 2    253
# 3    253
# 4    132
# ...

# %%
comp["vendor_name"].duplicated()
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 204     True
# 205     True
# 206    False
# 207    False
# 208     True
# Name: vendor_name, Length: 209, dtype: bool

# %%
comp[~comp["vendor_name"].duplicated(keep=False)]
# Out:
#     vendor_name   model_name  MYCT  MMIN  MMAX  CACH  CHMIN  CHMAX  PRP  ERP
# 0       adviser        32/60   125   256  6000   256     16    128  198  199
# 62   four-phase     2000/260   125   512  1000     0      8     20   36   19
# 137   microdata  seq.ms/3200   150   512  4000     0      8    128   30   33
# 206      sratus           32   125  2000  8000     0      2     14   52   41

# %%
comp[~comp["vendor_name"].duplicated()]
# Out:
#       vendor_name       model_name  MYCT  MMIN   MMAX  CACH  CHMIN  CHMAX  \
# 0         adviser            32/60   125   256   6000   256     16    128
# 1          amdahl           470v/7    29  8000  32000    32      8     32
# 10         apollo            dn320   400  1000   3000     0      1      2
# 12           basf             7/65    60  2000   8000    65      1      8
# 14            bti             5000   350    64     64     0      1      4
# 16      burroughs            b1955   167   524   2000     8      4     15
# 24          c.r.d         68/10-80   320   128   6000     0      1     12
# 30            cdc    cyber:170/750    25  1310   2620   131     12     24
# 39         cambex           1636-1    50  1000   4000     8      3      5
# 44            dec   decsys:10:1091   133  1000  12000     9      3     12
# 50             dg    eclipse:c/350   700   384   8000     0      1      1
# 57      formation        f4000/100   800   256   8000     0      1      4
# ...

# %%
# drop_duplicates method in pandas


comp.drop_duplicates(subset=["vendor_name"],keep=False)
# Out:
#     vendor_name   model_name  MYCT  MMIN  MMAX  CACH  CHMIN  CHMAX  PRP  ERP
# 0       adviser        32/60   125   256  6000   256     16    128  198  199
# 62   four-phase     2000/260   125   512  1000     0      8     20   36   19
# 137   microdata  seq.ms/3200   150   512  4000     0      8    128   30   33
# 206      sratus           32   125  2000  8000     0      2     14   52   41

# %%
# drop_duplicates method in pandas


comp.drop_duplicates(subset=["vendor_name"])
# Out:
#       vendor_name       model_name  MYCT  MMIN   MMAX  CACH  CHMIN  CHMAX  \
# 0         adviser            32/60   125   256   6000   256     16    128
# 1          amdahl           470v/7    29  8000  32000    32      8     32
# 10         apollo            dn320   400  1000   3000     0      1      2
# 12           basf             7/65    60  2000   8000    65      1      8
# 14            bti             5000   350    64     64     0      1      4
# 16      burroughs            b1955   167   524   2000     8      4     15
# 24          c.r.d         68/10-80   320   128   6000     0      1     12
# 30            cdc    cyber:170/750    25  1310   2620   131     12     24
# 39         cambex           1636-1    50  1000   4000     8      3      5
# 44            dec   decsys:10:1091   133  1000  12000     9      3     12
# 50             dg    eclipse:c/350   700   384   8000     0      1      1
# 57      formation        f4000/100   800   256   8000     0      1      4
# ...
